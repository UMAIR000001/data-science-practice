# %% [markdown]
# # LEVEL 1: Must-Know Basics
#
# - Load deliveries.csv into a DataFrame.
#
# - Print the first 5 rows and last 5 rows.
#
# - Check the shape of the dataset.
#
# - Check column names.
#
# - Get summary statistics using .describe().
#
# - Check data types and null counts using .info().

# %% [markdown]
# ### Loading Data

# %%
import pandas as pd
deliveries=pd.read_csv("deliveries.csv")
matches=pd.read_csv("matches.csv")

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
deliveries.tail()
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 260915   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
#
#         ball   batter         bowler non_striker  batsman_runs  extra_runs  \
# 260915     5  SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6  VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2  SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 260915           1         NaN          0              NaN            NaN
# 260916           1         NaN          0              NaN            NaN
# 260917           1         NaN          0              NaN            NaN
# 260918           1         NaN          0              NaN            NaN
# 260919           1         NaN          0              NaN            NaN
#
#        fielder
# 260915     NaN
# 260916     NaN
# 260917     NaN
# 260918     NaN
# 260919     NaN

# %%
deliveries.shape
# Out:
# (260920, 17)

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       1.000000       0.000000
# 75%         1.000000       0.000000       1.000000       0.000000
# max         6.000000       7.000000       7.000000       1.000000

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %% [markdown]
#  # 🎯 PROFESSIONAL RATING
# ### ⭐ 9 / 10
#
# Why not 10?
#
# Minor duplication
#
# Slightly extra file loaded before it’s needed
#
# Conceptually: STRONG

# %% [markdown]
# # LEVEL 2: Selection & Filtering
#
# - Select the "batter" column and print the first 10 values.
#
# - Select multiple columns: "batter" and "batsman_runs" and print first 10 rows.
#
# - Filter all rows where batsman_runs == 6.
#
# - Filter all rows where batting_team == "Mumbai Indians" and batsman_runs == 6.
#
# - Use .iloc[] to print first 5 rows and first 3 columns.
#
# - Use .loc[] to print rows 10 to 20 and columns "batter" and "batsman_runs".

# %%
deliveries["batter"].head(10)

# %%
deliveries[["batter","batsman_runs"]]
# Out:
#              batter  batsman_runs
# 0        SC Ganguly             0
# 1       BB McCullum             0
# 2       BB McCullum             0
# 3       BB McCullum             0
# 4       BB McCullum             0
# ...             ...           ...
# 260915      SS Iyer             1
# 260916      VR Iyer             1
# 260917      VR Iyer             1
# 260918      SS Iyer             1
# 260919      VR Iyer             1
#
# [260920 rows x 2 columns]

# %%
deliveries[deliveries["batsman_runs"]==6]
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 10        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 20        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 25        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 60        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 65        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260868   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260869   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260889   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260895   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260908   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
#         over  ball              batter         bowler         non_striker  \
# 10         1     4         BB McCullum         Z Khan          SC Ganguly
# 20         3     2         BB McCullum      AA Noffke          SC Ganguly
# 25         3     7         BB McCullum      AA Noffke          SC Ganguly
# 60         9     5         BB McCullum       SB Joshi          RT Ponting
# 65        10     4          RT Ponting      JH Kallis         BB McCullum
# ...      ...   ...                 ...            ...                 ...
# 260868     2     2             VR Iyer        B Kumar  Rahmanullah Gurbaz
# 260869     2     3             VR Iyer        B Kumar  Rahmanullah Gurbaz
# 260889     5     3             VR Iyer    T Natarajan  Rahmanullah Gurbaz
# 260895     6     3  Rahmanullah Gurbaz  Shahbaz Ahmed             VR Iyer
# 260908     8     4  Rahmanullah Gurbaz  Shahbaz Ahmed             VR Iyer
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 10                 6           0           6         NaN          0
# 20                 6           0           6         NaN          0
# 25                 6           0           6         NaN          0
# 60                 6           0           6         NaN          0
# 65                 6           0           6         NaN          0
# ...              ...         ...         ...         ...        ...
# 260868             6           0           6         NaN          0
# 260869             6           0           6         NaN          0
# 260889             6           0           6         NaN          0
# 260895             6           0           6         NaN          0
# 260908             6           0           6         NaN          0
#
#        player_dismissed dismissal_kind fielder
# 10                  NaN            NaN     NaN
# 20                  NaN            NaN     NaN
# 25                  NaN            NaN     NaN
# 60                  NaN            NaN     NaN
# 65                  NaN            NaN     NaN
# ...                 ...            ...     ...
# 260868              NaN            NaN     NaN
# 260869              NaN            NaN     NaN
# 260889              NaN            NaN     NaN
# 260895              NaN            NaN     NaN
# 260908              NaN            NaN     NaN
#
# [13051 rows x 17 columns]

# %%
deliveries[(deliveries["batting_team"]=="Mumbai Indians")&(deliveries["batsman_runs"]==6)]
# Out:
#         match_id  inning    batting_team                 bowling_team  over  \
# 723       335985       1  Mumbai Indians  Royal Challengers Bangalore     4
# 765       335985       1  Mumbai Indians  Royal Challengers Bangalore    11
# 798       335985       1  Mumbai Indians  Royal Challengers Bangalore    17
# 801       335985       1  Mumbai Indians  Royal Challengers Bangalore    17
# 808       335985       1  Mumbai Indians  Royal Challengers Bangalore    18
# ...          ...     ...             ...                          ...   ...
# 259513   1426305       2  Mumbai Indians         Lucknow Super Giants    16
# 259524   1426305       2  Mumbai Indians         Lucknow Super Giants    18
# 259525   1426305       2  Mumbai Indians         Lucknow Super Giants    18
# 259529   1426305       2  Mumbai Indians         Lucknow Super Giants    19
# 259535   1426305       2  Mumbai Indians         Lucknow Super Giants    19
#
#         ball         batter         bowler      non_striker  batsman_runs  \
# 723        7  ST Jayasuriya      JH Kallis       RV Uthappa             6
# 765        6     RV Uthappa  R Vinay Kumar          PR Shah             6
# 798        2       AM Nayar  R Vinay Kumar       SM Pollock             6
# 801        5     SM Pollock  R Vinay Kumar         AM Nayar             6
# 808        6     SM Pollock        P Kumar  Harbhajan Singh             6
# ...      ...            ...            ...              ...           ...
# 259513     6     Naman Dhir      KH Pandya     Ishan Kishan             6
# 259524     3     Naman Dhir    Mohsin Khan     Ishan Kishan             6
# 259525     4     Naman Dhir    Mohsin Khan     Ishan Kishan             6
# 259529     1     Naman Dhir  Naveen-ul-Haq     Ishan Kishan             6
# 259535     7     Naman Dhir  Naveen-ul-Haq       R Shepherd             6
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 723              0           6         NaN          0              NaN
# 765              0           6         NaN          0              NaN
# 798              0           6         NaN          0              NaN
# 801              0           6         NaN          0              NaN
# 808              0           6         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 259513           0           6         NaN          0              NaN
# 259524           0           6         NaN          0              NaN
# 259525           0           6         NaN          0              NaN
# 259529           0           6         NaN          0              NaN
# 259535           0           6         NaN          0              NaN
#
#        dismissal_kind fielder
# 723               NaN     NaN
# 765               NaN     NaN
# 798               NaN     NaN
# 801               NaN     NaN
# 808               NaN     NaN
# ...               ...     ...
# 259513            NaN     NaN
# 259524            NaN     NaN
# 259525            NaN     NaN
# 259529            NaN     NaN
# 259535            NaN     NaN
#
# [1685 rows x 17 columns]

# %%
#Use .iloc[] to print first 5 rows and first 3 columns
deliveries.iloc[0:5,0:3]
# Out:
#    match_id  inning           batting_team
# 0    335982       1  Kolkata Knight Riders
# 1    335982       1  Kolkata Knight Riders
# 2    335982       1  Kolkata Knight Riders
# 3    335982       1  Kolkata Knight Riders
# 4    335982       1  Kolkata Knight Riders

# %%
#Use .loc[] to print rows 10 to 20 and columns "batter" and "batsman_runs".
deliveries.loc[10:20,["batter","batsman_runsA"]]
# Out:
#          batter  batsman_runs
# 10  BB McCullum             6
# 11  BB McCullum             4
# 12  BB McCullum             0
# 13   SC Ganguly             0
# 14   SC Ganguly             0
# 15   SC Ganguly             0
# 16  BB McCullum             4
# 17  BB McCullum             1
# 18   SC Ganguly             0
# 19  BB McCullum             0
# 20  BB McCullum             6

# %% [markdown]
# # 🎯 PROFESSIONAL RATING
# ## ⭐ 8.5 / 10
# Breakdown:
#
# Concepts: Excellent
#
# Syntax understanding: Strong
#
# One column-name mistake: −1.5

# %% [markdown]
# # LEVEL 3: Grouping & Aggregation
#
# - Calculate total runs scored by each batter.
#
# - Calculate total balls faced by each batter.
#
# - Calculate total runs scored by each team.
#
# - Calculate strike rate for each batter (total_runs / balls_faced * 100).
#
# - Use .agg() to get both total runs and total balls faced per batter in one line.
#
# - Use .reset_index() after your groupby to convert index to column.
#
# - Find top 5 batters by total runs.
#
# - Find top 5 batters by strike rate, but only include those who faced ≥ 100 balls.

# %%
deliveries.groupby('batter')["batsman_runs"].sum().sort_values(ascending=False).reset_index()
# Out:
#            batter  batsman_runs
# 0         V Kohli          8014
# 1        S Dhawan          6769
# 2       RG Sharma          6630
# 3       DA Warner          6567
# 4        SK Raina          5536
# ..            ...           ...
# 668       S Ladda             0
# 669  S Lamichhane             0
# 670  Abdur Razzak             0
# 671   SS Cottrell             0
# 672       KM Asif             0
#
# [673 rows x 2 columns]

# %%
deliveries.groupby('batter').size().sort_values(ascending=False).reset_index()
deliveries.groupby('batting_team')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(10)
#Calculate strike rate for each batter (total_runs / balls_faced * 100).
total_runs=deliveries.groupby('batter')["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
deliveries.groupby("batter").agg(
    total_runs=('batsman_runs','sum'),
    total_balls=('batsman_runs','size')
).reset_index()
deliveries.groupby('batting_team')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(10)
deliveries.groupby('batter')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(5)

total_runs=deliveries.groupby(['batter','ball'])["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
strike_rate=(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
strike_rate=deliveries.groupby(['batter'])["ball"].sum().reset_index()
strike_rate[strike_rate["ball"]>=5000].head(20)

total_runs=deliveries.groupby(['batter','ball'])["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
strike_rate=(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
strike_rate=deliveries.groupby(['batter'])["ball"].sum().reset_index()
stri
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[320], line 24
#      22 strike_rate=(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
#      23 strike_rate=deliveries.groupby(['batter'])["ball"].sum().reset_index()
# ---> 24 stri
#
# NameError: name 'stri' is not defined

# %%
deliveries.groupby('batter').size().sort_values(ascending=False).reset_index()
# Out:
#             batter     0
# 0          V Kohli  6236
# 1         S Dhawan  5483
# 2        RG Sharma  5183
# 3        DA Warner  4849
# 4         SK Raina  4177
# ..             ...   ...
# 668     YA Abdulla     1
# 669  DP Vijaykumar     1
# 670  Y Prithvi Raj     1
# 671      S Kaushik     1
# 672  NJ Rimmington     1
#
# [673 rows x 2 columns]

# %%
deliveries.groupby('batting_team')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(10)
# Out:
#                   batting_team  batsman_runs
# 0               Mumbai Indians         39946
# 1        Kolkata Knight Riders         37149
# 2          Chennai Super Kings         36739
# 3  Royal Challengers Bangalore         35810
# 4             Rajasthan Royals         33074
# 5              Kings XI Punjab         28541
# 6          Sunrisers Hyderabad         27641
# 7             Delhi Daredevils         23022
# 8               Delhi Capitals         14229
# 9              Deccan Chargers         10885

# %%
#Calculate strike rate for each batter (total_runs / balls_faced * 100).
total_runs=deliveries.groupby('batter')["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
# Out:
#               batter           0
# 0             L Wood  300.000000
# 1         B Stanlake  250.000000
# 2    J Fraser-McGurk  220.000000
# 3      R Sai Kishore  216.666667
# 4           Umar Gul  205.263158
# ..               ...         ...
# 668         JL Denly    0.000000
# 669      Sunny Gupta    0.000000
# 670           U Kaul    0.000000
# 671          C Nanda    0.000000
# 672        IC Pandey    0.000000
#
# [673 rows x 2 columns]

# %%
deliveries.groupby("batter").agg(
    total_runs=('batsman_runs','sum'),
    total_balls=('batsman_runs','size')
).reset_index()
# Out:
#              batter  total_runs  total_balls
# 0    A Ashish Reddy         280          196
# 1          A Badoni         634          505
# 2        A Chandila           4            7
# 3          A Chopra          53           75
# 4       A Choudhary          25           20
# ..              ...         ...          ...
# 668   Yashpal Singh          47           67
# 669     Younis Khan           3            7
# 670   Yudhvir Singh          22           16
# 671    Yuvraj Singh        2754         2207
# 672          Z Khan         117          141
#
# [673 rows x 3 columns]

# %%
deliveries.groupby('batting_team')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(10)
# Out:
#                   batting_team  batsman_runs
# 0               Mumbai Indians         39946
# 1        Kolkata Knight Riders         37149
# 2          Chennai Super Kings         36739
# 3  Royal Challengers Bangalore         35810
# 4             Rajasthan Royals         33074
# 5              Kings XI Punjab         28541
# 6          Sunrisers Hyderabad         27641
# 7             Delhi Daredevils         23022
# 8               Delhi Capitals         14229
# 9              Deccan Chargers         10885

# %%
deliveries.groupby('batter')["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(5)
# Out:
#       batter  batsman_runs
# 0    V Kohli          8014
# 1   S Dhawan          6769
# 2  RG Sharma          6630
# 3  DA Warner          6567
# 4   SK Raina          5536

# %%
total_runs=deliveries.groupby(['batter','ball'])["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
strike_rate=(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
strike_rate=deliveries.groupby(['batter'])["ball"].sum().reset_index()
strike_rate[strike_rate["ball"]>=5000].head(20)
# Out:
#                batter   ball
# 30     AB de Villiers  12684
# 32       AC Gilchrist   5422
# 39         AD Russell   5851
# 43           AJ Finch   6105
# 50          AM Rahane  13331
# 64          AT Rayudu  12565
# 102       BB McCullum   8092
# 124          CH Gayle  12774
# 146         DA Miller   8005
# 147         DA Warner  17086
# 173  DPMD Jayawardene   5536
# 177          DR Smith   6280
# 188      F du Plessis  12212
# 194         G Gambhir  12619
# 203        GJ Maxwell   6757
# 213         HH Pandya   6645
# 231      Ishan Kishan   7050
# 242        JC Buttler   9137
# 250         JH Kallis   8122
# 261         JP Duminy   6132

# %%
total_runs=deliveries.groupby(['batter','ball'])["batsman_runs"].sum()
balls_faced=deliveries.groupby('batter').size()
strike_rate=(total_runs / balls_faced * 100).sort_values(ascending=False).reset_index()
strike_rate=deliveries.groupby(['batter'])["ball"].sum().reset_index()
stri
# Out:
#   Cell In[319], line 5
#     strike_rate['ball']>=5000.rest_index()
#                              ^
# SyntaxError: invalid decimal literal
